# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Creating DataFrame using CSV file

#df=pd.read_csv("C:\\Users\\sibag\\OneDrive\\Desktop\\my file\\EDA project\\google_cleaned (2).csv")
#df.head(6)

# %%
#1. Display Top 5 Rows of The Dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 x=[1,4,8,12]
#       3 y=[3,9,12]
# ----> 4 plt.plot(x,y)
#       5 plt.show()
#
# NameError: name 'plt' is not defined
